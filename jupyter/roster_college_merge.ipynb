# %%
import pandas as pd

# %%
# %store -r nfl_weather_df
nfl_weather_df.head()
# Out:
#                  id           home_team  home_score            away_team  \
# 10073  200901030crd   Arizona Cardinals          30      Atlanta Falcons
# 10074  200901030sdg  San Diego Chargers          23   Indianapolis Colts
# 10075  200901040min   Minnesota Vikings          14  Philadelphia Eagles
# 10076  200901040mia      Miami Dolphins           9     Baltimore Ravens
# 10077  200901100oti    Tennessee Titans          10     Baltimore Ravens
#
#        away_score  temperature  wind_chill humidity  wind_mph  \
# 10073          24           72         NaN      NaN       NaN
# 10074          17           54         NaN      78%       7.0
# 10075          26           72         NaN      NaN       NaN
# 10076          27           74         NaN      72%      10.0
# 10077          13           53         NaN      68%      12.0
#
#                                               weather       date      date2  \
# ...

# %%
# %store -r gameinfo_df
gameinfo_df.head()
# Out:
#   type   game_id home_team away_team  week  season state_of_game  \
# 0  reg  20090910       PIT       TEN     1    2009          POST
# 1  reg  20090913       CLE       MIN     1    2009          POST
# 2  reg  20090913        NO       DET     1    2009          POST
# 3  reg  20090913        TB       DAL     1    2009          POST
# 4  reg  20090913       HOU       NYJ     1    2009          POST
#
#                                             game_url  home_score  away_score
# 0  http://www.nfl.com/liveupdate/game-center/2009...          13          10
# 1  http://www.nfl.com/liveupdate/game-center/2009...          20          34
# 2  http://www.nfl.com/liveupdate/game-center/2009...          45          27
# 3  http://www.nfl.com/liveupdate/game-center/2009...          21          34
# 4  http://www.nfl.com/liveupdate/game-center/2009...           7          24

# %%
# %store -r roster_df
roster_df.head()
# Out:
#    season full_player_name abbr_player_name team position first_name last_name
# 0    2009      Aaron Brown          A.Brown  DET       RB      Aaron     Brown
# 1    2009    Aaron Rodgers        A.Rodgers   GB       QB      Aaron   Rodgers
# 2    2009    Aaron Stecker        A.Stecker  ATL       RB      Aaron   Stecker
# 3    2009  Adrian Peterson       A.Peterson  CHI       RB     Adrian  Peterson
# 4    2009  Adrian Peterson       A.Peterson  MIN       RB     Adrian  Peterson

# %%
# %store -r df3
df3.head()

# %store -r df2
df2
# Out:
#                      name first_name     last_name               college  \
# 0           Isaako Aaitui     Isaako        Aaitui                   NaN
# 1             Faye Abbott       Faye        Abbott              Syracuse
# 2            Vince Abbott      Vince        Abbott            Washington
# 3           Duke Abbruzzi       Duke      Abbruzzi          Rhode Island
# 4      Karim Abdul-Jabbar      Karim  Abdul-Jabbar                  UCLA
# 5        Isa Abdul-Quddus        Isa  Abdul-Quddus               Fordham
# 6          Hamza Abdullah      Hamza      Abdullah        Washington St.
# 7         Husain Abdullah     Husain      Abdullah        Washington St.
# 8         Khalid Abdullah     Khalid      Abdullah             Mars Hill
# 9          Rabih Abdullah      Rabih      Abdullah                Lehigh
# 10         Rahim Abdullah      Rahim      Abdullah               Clemson
# 11              Fred Abel       Fred          Abel            Washington
# ...

# %%
roster_merge_df = roster_df.merge(right = df2, on = ['first_name', 'last_name'], how = 'left')
roster_merge_df = roster_merge_df[['full_player_name', 'first_name', 'last_name', 'position_x', 'college', 'team']]

col_names = ['full_name', 'first_name', 'last_name', 'position', 'college', 'team']

roster_merge_df.columns = col_names



# roster_merge_df['college'].value_counts()

roster_merge_df = roster_merge_df.drop_duplicates().reset_index(drop = True)

# len(roster_merge_df['college'])


# roster_merge_df.loc[roster_merge_df['full_name'] == 'Aaron Rodgers']

roster_merge_df.head(10)
# Out:
#          full_name first_name last_name position           college team
# 0      Aaron Brown      Aaron     Brown       RB         Minnesota  DET
# 1      Aaron Brown      Aaron     Brown       RB               TCU  DET
# 2    Aaron Rodgers      Aaron   Rodgers       QB        California   GB
# 3    Aaron Stecker      Aaron   Stecker       RB         Wisconsin  ATL
# 4  Adrian Peterson     Adrian  Peterson       RB  Georgia Southern  CHI
# 5  Adrian Peterson     Adrian  Peterson       RB          Oklahoma  CHI
# 6  Adrian Peterson     Adrian  Peterson       RB  Georgia Southern  MIN
# 7  Adrian Peterson     Adrian  Peterson       RB          Oklahoma  MIN
# 8   Ahmad Bradshaw      Ahmad  Bradshaw       RB          Marshall  NYG
# 9      Ahman Green      Ahman     Green       RB          Nebraska   GB

# %%
# Dataframe seems to be duplicating school/team for some players (see Adrian Peterson)

#Create copy of roster_merge_df
weird_df = roster_merge_df.copy()

#Create blank list
#This will tell us the indexes that are duplicates
dup_list = []

# Remove the college so that we can see true duplicates (the first index of each player is correct)
weird_df = weird_df[['full_name', 'first_name', 'last_name', 'position', 'team']]

#Add duplicate results to list
dup_list = weird_df.duplicated().to_list()

# %%
# Remove the duplicates from the original roster merge dataframe
for i in range(len(roster_merge_df)):
    if dup_list[i] == True:
        roster_merge_df = roster_merge_df.drop(index = i)

# %%
# Reset the index       
roster_merge_df.reset_index(drop = True)

roster_merge_df
# Out:
#               full_name first_name   last_name position             college  \
# 0           Aaron Brown      Aaron       Brown       RB           Minnesota
# 2         Aaron Rodgers      Aaron     Rodgers       QB          California
# 3         Aaron Stecker      Aaron     Stecker       RB           Wisconsin
# 4       Adrian Peterson     Adrian    Peterson       RB    Georgia Southern
# 6       Adrian Peterson     Adrian    Peterson       RB    Georgia Southern
# 8        Ahmad Bradshaw      Ahmad    Bradshaw       RB            Marshall
# 9           Ahman Green      Ahman       Green       RB            Nebraska
# 10          Ahmard Hall     Ahmard        Hall       FB               Texas
# 11         Albert Young     Albert       Young       RB                Iowa
# 12           Alex Smith       Alex       Smith       TE                Utah
# 14           Alex Smith       Alex       Smith       QB                Utah
# ...

# %%
# %store roster_merge_df
# Out:
# Stored 'roster_merge_df' (DataFrame)
